# %% [markdown]
# ![title](Header__0007_3.png "Header")
# ___
# # Chapter 3 - Exploring correlation between variables
#
# ## Segment 4 - Starting with parametric methods in pandas and scipy

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
from pylab import rcParams

import scipy
from scipy.stats.stats import pearsonr

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8, 4
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### The Pearson Correlation

# %%
address = 'mtcars.csv'
cars = pd.read_csv(address)
cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
sb.pairplot(cars)

# %%
pd.plotting.scatter_matrix(cars);

# %%
X = cars[['mpg', 'hp', 'qsec','wt']]
sb.pairplot(X)

# %%
pd.plotting.scatter_matrix(X);

# %% [markdown]
# ### Using scipy to calculate the Pearson correlation coefficient

# %%
mpg = cars['mpg']
hp = cars['hp']
qsec = cars['qsec']
wt = cars['wt']

pearsonr_coefficient, p_value = pearsonr(mpg, hp)
print('mpg, hp PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient))
print(f'mpg, hp p_value {p_value:.7f}')
# Out:
# mpg, hp PearsonR Correlation Coefficient -0.776
# mpg, hp p_value 0.0000002

# %%
pearsonr_coefficient, p_value = pearsonr(mpg, qsec)
print('mpg, wt PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient))
print(f'mpg, wt p_value {p_value:.7f}')
# Out:
# mpg, wt PearsonR Correlation Coefficient 0.419
# mpg, wt p_value 0.0170820

# %%
pearsonr_coefficient, p_value = pearsonr(mpg, wt)
print('mpg, wt PearsonR Correlation Coefficient %0.3f' % (pearsonr_coefficient))
print(f'mpg, wt p_value {p_value:.7f}')
# Out:
# mpg, wt PearsonR Correlation Coefficient -0.868
# mpg, wt p_value 0.0000000

# %% [markdown]
# ### Using pandas to calculate the Pearson correlation coefficient

# %%
corr = X.corr()
corr
# Out:
#            mpg        hp      qsec        wt
# mpg   1.000000 -0.776168  0.418684 -0.867659
# hp   -0.776168  1.000000 -0.708223  0.658748
# qsec  0.418684 -0.708223  1.000000 -0.174716
# wt   -0.867659  0.658748 -0.174716  1.000000

# %% [markdown]
# ### Using Seaborn to visualize the Pearson correlation coefficient

# %%
sb.heatmap(corr,xticklabels=corr.columns.values, yticklabels=corr.columns.values)
